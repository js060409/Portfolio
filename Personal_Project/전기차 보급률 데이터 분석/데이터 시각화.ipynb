# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# ![asdasdasdasdasd.PNG](data:image/png;base64,...)

# %% [markdown]
# **20611 박종상 통계청 자료를 바탕으로 자료 분석하기
# -연도별 전기차 현황**

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **파일 업로드 하기**

# %% [markdown]
# **분석에 사용할 자료**
# https://drive.google.com/file/d/1KdCQ9_VyBKgkV4W4EZZk-0LYRMrjLWej/view?usp=sharing

# %%
from google.colab import files
uploaded = files.upload()

## 데이터 처리 방식은 엑셀 파일인 .csv 형식으로 진행합니다.
# Out:
#      <input type="file" id="files-0846367b-d729-4a97-8307-06287a772bf5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0846367b-d729-4a97-8307-06287a772bf5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **데이터 분석에 사용할 파일 불러오기**

# %%
# csv 라이브러리 임포트
import csv

f = open('한국전력공사_지역별 전기차 현황정보_20230331.csv', encoding = 'ISO-8859-1')         # 파일 오픈
data = csv.reader(f)         # 파일 읽기 reader
next(data)                   # 파일 헤더 건너뛰기
data = list(data)            # 파일 리스트로 바꾸기

#파일 불러 올때 f = open('')안에 있는 글씨를 자신이 불러온 파일의 이름(확장자명 포함)으로 설정해야합니다.

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **데이터 분석 과정** -글씨체 설정하기 (필수)

# %%
import matplotlib.pyplot as plt
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
#글씨체를 나눔 고딕체로 변경

plt.rc('font', family='NanumGothic')
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (20.1 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 서울

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[1]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('서울 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 인천

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[2]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('인천 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 경기

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[3]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('경기 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 강원

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[4]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('강원 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 충북

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[5]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('충북 전기차 현황 22년 1월 ~ 23년 3월')           #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 충남

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[6]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('충남시 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 대전

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[7]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('대전 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 세종

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[8]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('세종 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 경북

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[9]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('경북 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 대구

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[10]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('대구 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 전북

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[11]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('전북 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 전남

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[12]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('전남 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 광주

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[13]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('광주 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 경남

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[14]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('경남 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 부산

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[15]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('부산 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 울산

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[16]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('울산 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 제주

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[17]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('제주 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'blue')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **그래프 작성 코드** - 종합

# %%
import matplotlib.pyplot as plt
import numpy as np
month = ['22-1','22-2','22-3','22-4','22-5','22-6','22-7','22-8','22-9','22-10','22-11','22-12','23-1','23-2','23-3']
scale = []
for row in data:
  scale.append(float(row[18]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                      #그래프 적용 글씨체
plt.title('종합 전기차 현황 22년 1월 ~ 23년 3월')         #그래프 제목
plt.bar(month, scale, color = 'red')                       #그래프 그리기

plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **결론**

# %% [markdown]
# ![종합.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 전반적으로 보았을때 전기차의 수가 늘어나는 경향을 보인다 그 이유는 크게 4가지로 나눌수 있다
#
# *   친환경적 소비 가치관의 확대
# *   전기차 배터리 가격 하락 -> 전기차 가격 하락
# *   정부 보조금 지급
# *   전기차 인프라의 확대

# %% [markdown]
# ![다운로드.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 위 그래프는 년도 당 전기차 생산가격 그래프이다 (하락세를 보임)

# %% [markdown]
# ![캡처.PNG](data:image/png;base64,...)

# %% [markdown]
# 전기차 관련 지원 및 정책이 시행되면서 일반 사람들도 전기차를 부담없이 접할수 있게 되었다.

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **소스코드 공유**

# %%
from google.colab import files
uploaded = files.upload()

## 데이터 처리 방식은 엑셀 파일인 .csv 형식으로 진행합니다.

# %%
# csv 라이브러리 임포트
import csv

f = open('업로드한 파일이름', encoding = 'ISO-8859-1')         # 파일 오픈
data = csv.reader(f)         # 파일 읽기 reader
next(data)                   # 파일 헤더 건너뛰기
data = list(data)            # 파일 리스트로 바꾸기

#파일 불러 올때 f = open('')안에 있는 글씨를 자신이 불러온 파일의 이름(확장자명 포함)으로 설정해야합니다.
#파일 분석이 진행되지 않을때는 encoding 뒤 'ISO-8859-1'를 UTF-8로 변경하면 됩니다. (문자열 구분설정 오류)

# %%
import matplotlib.pyplot as plt
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
plt.rc('font', family='NanumGothic')
#글씨체를 나눔 고딕체로 변경 (필수요소 이니 꼭 해주세요)

# %%
import matplotlib.pyplot as plt
import numpy as np
xaxis = []
yaxis = []
for row in data:
  scale.append(float(row[]))

plt.figure(dpi = 200)                                        #해상도 조절
plt.figure(figsize=(10, 5))                                  #그래프 사이즈 조절
plt.rc('font', family = 'NanumGothic')                       #그래프 적용 글씨체
plt.title()            #그래프 제목
plt.bar(xaxis, yaxis, color = '')                        #그래프 그리기
plt.show()

# xaxis 리스트에는 x축으로 사용할 문자들을 '적용할 문자1', '적용할 문자2' 등의 형식으로 추가해 주세요
# yaxis는 비워둡니다
# 그래프 비율이 맞지 않을때는 figsize의 괄호 안 수치를 변경하시면 됩니다 (기본 1 : 2)
# plt.title()의 괄호안에는 '사용할 제목' 형식으로 추가해주세요
# plt.bar에 마지막 color = ' '부분에 ' ' 안에 사용할 색을 적어주시면 됩니다.
# 추가적으로 코드에 궁금한 점이 있거나 오류 발견시 20611 박종상에게 연락주세요

# %% [markdown]
# --------------------------------------------------------------------------------
